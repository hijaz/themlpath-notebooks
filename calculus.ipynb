# %% [markdown]
# <h3><a href="https://themlpath.com">< The ML Path</a></h3>
#
#
# - [ 1.1 - Concepts ](#2.1)
# - [ 1.2 - Common Derivatives ](#2.2)
# - [ 1.3 - Calculating Derivative ](#2.3)
# - [ 1.4 - Non-Differentiable Functions ](#2.4)
# - [ 1.5 - Optimization ](#2.5)
# - [ 1.6 - Gradients ](#2.6)
# - [ 1.7 - Gradient Descent ](#2.7)
# - [ 1.8 - NN Optimization ](#2.8)
# - [ 1.9 - Newtons Method ](#2.9)

# %% [markdown]
# <a name="2"></a>
#
# ## Calculus

# %% [markdown]
# <a name="2.1"></a>
#
# ### Concepts
#
# **Derivative**: A derivative is a mathematical concept that shows how a quantity changes when something else changes a tiny bit. It's like a way to measure how fast something is changing at a specific point. In simple terms, it helps us understand how things move or vary when we make a tiny adjustment to something else.
#
# Example: Looking at the speedometer of a car at a given instance is like taking the derivative of position over time. It tells us the rate of change of position with respect to time. Taking **integral** would be like adding the speedometer values of all instances and adding them up to get the total position change (distance covered).
#
# **Tangent**: A tangent is like a straight line that just touches the curve of a shape at one point. Imagine you have a curvy line drawn on a piece of paper. If you draw a straight line that touches that curvy line at one specific spot, that straight line is a tangent.
#
# Now, differentiation is closely related to tangents. When you find the derivative of a function at a particular point, you're figuring out the slope of the tangent line to the curve of that function at that point. In other words, the derivative tells you how steep the curve is exactly where the tangent touches it.
#
# So, differentiation helps you find the slope of the tangent line, which gives you a really good idea of how the curve is behaving at that specific point. It's like zooming in super close to a roller coaster track and seeing exactly how steep it is at the spot where the ride is happening.
#
# If the tangent is **horizontal** and touches curve from above, it indicates a **local maximum**, if it touches from below it indicates a **local minimum**.
#
# **Differentiation**: The process of finding a derivative. Calculating how much a quantity changes with respect to a small change in another related quantity. In Machine Learning, it helps understand how changing input variables affects the output.
#
# Example: If you have a car moving along a road, differentiation can help you find how its speed is changing at a specific moment.
#
# **Integration**: Adding up small quantities to find a total or accumulated amount.
#
# Example: If you want to know the total area of a strangely shaped field, integration helps you add up tiny parts of the field to find the whole area.
#
#
# **Backpropagation**: A technique used in training neural networks, which involves calculating gradients (derivatives) of the loss function with respect to the network's weights. It helps adjust the weights to minimize the error and improve the network's performance.
#
#
# The **derivative of the inverse function**, represents how fast the inverse function's output changes in response to changes in its input. In other words, it tells us how the output of the inverse function responds to small changes in the input.
#
# The inverse function "undoes" what the original function does. If the original function made values bigger, the inverse makes them smaller, and vice versa.
#
# The rate of change of the inverse function at a point is the reciprocal (1 divided by) the rate of change of the original function at the corresponding point.
#
# In simpler terms, the derivative of the inverse function helps us understand how the input of the inverse function responds to changes in its output. It's a way to measure how the reverse process works, just like the original derivative measures how the original process works.
#
# The **exponential function e^x** (e is the Euler number) is a mathematical function that represents exponential growth. It's a fundamental function in mathematics, and its derivative has a special property: the derivative of e^x is itself, which makes it unique and powerful.
#
# The **natural logarithm log base e of x** also written as ln(x) is the inverse of e^x.
#
# #### Properties of Derivatives
#
# **Multiplication by Scalars:**
#
# The derivative of a constant times a function is the constant times the derivative of the function.
#
# **Sum Rule:**
#
# The derivative of a sum of functions is the sum of their individual derivatives.
#
# **Chain Rule:**
#
# The chain rule is used when functions are composed (one inside another). It states that the derivative of a composition of functions is the derivative of the outer function multiplied by the derivative of the inner function.
#
# **Product Rule:**
#
# The product rule is used when you have a function that is a product of two functions. It states that the derivative of a product of functions is the derivative of the first function times the second function, plus the first function times the derivative of the second function.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the original function and its inverse
def original_function(x):
    return x**2

def inverse_function(x):
    return np.sqrt(x)

# Define the range of x values (excluding 0 for the division by zero)
x_vals = np.linspace(0.01, 5, 400)

# Calculate the original and inverse function values
f_x = original_function(x_vals)
f_inv_x = inverse_function(x_vals)

# Calculate the derivatives
f_prime_x = 2 * x_vals
f_inv_prime_x = 1 / f_prime_x  # Corrected derivative of the inverse function

# Create a single plot
plt.figure(figsize=(10, 6))

# Plot the original function and its derivative
plt.plot(x_vals, f_x, label='$f(x) = x^2$')
plt.plot(x_vals, f_prime_x, label="$f'(x) = 2x$", linestyle='--')

# Plot the inverse function and its derivative (excluding x = 0)
plt.plot(x_vals, f_inv_x, label='$f^{-1}(x) = \sqrt{x}$')
plt.plot(x_vals, f_inv_prime_x, label="$(f^{-1})'(x) = \\frac{1}{2x}$", linestyle='--')  # Updated label

plt.xlabel('x')
plt.ylabel('y')
plt.title('Original Function, Inverse Function, and Their Derivatives')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <a name="2.2"></a>
#
# ### Common Derivatives

# %%
import numpy as np
import matplotlib.pyplot as plt

# Derivative of a Constant Function
x = np.linspace(-10, 10, 1000)
y = 5 * np.ones_like(x) # Constant function
plt.plot(x, y, label='Function')
plt.plot(x, 0*x, '--', label='Derivative')
plt.title("Constant Function y = 5")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

print("The derivative of a constant function is 0, since the slope does not change.")

# Derivative of a Linear Function
x = np.linspace(-10, 10, 1000)
y = 2*x + 1 # Linear function
plt.plot(x, y, label='Function')
plt.plot(x, 2*np.ones_like(x), '--', label='Derivative')
plt.title("Linear Function y = 2x + 1")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

print("The derivative of a linear function is the slope, which is constant. Here the slope is 2.")

# Derivative of a Quadratic Function
x = np.linspace(-5, 5, 1000)
y = x**2 # Quadratic function
plt.plot(x, y, label='Function')
plt.plot(x, 2*x, '--', label='Derivative')
plt.title("Quadratic Function y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

print("The derivative of a quadratic function is linear. Here the derivative is 2x.")

# Derivative of a Cubic Polynomial
x = np.linspace(-5, 5, 1000)
y = 2*x**3 - x**2 + 3 # Cubic polynomial
plt.plot(x, y, label='Function')
plt.plot(x, 6*x**2 - 2*x, '--', label='Derivative')
plt.title("Cubic Polynomial y = 2x^3 - x^2 + 3")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

print("The derivative of a cubic polynomial is a quadratic function. Here the derivative is 6x^2 - 2x.")

# Derivative of an Exponential Function
x = np.linspace(-5, 5, 1000)
y = 2**x # Exponential function
plt.plot(x, y, label='Function')
plt.plot(x, np.log(2)*2**x, '--', label='Derivative')
plt.title("Exponential Function y = 2^x")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

print("The derivative of an exponential function is itself. Here the derivative is 2^x.")
# Out:
# The derivative of a constant function is 0, since the slope does not change.
# The derivative of a linear function is the slope, which is constant. Here the slope is 2.
# The derivative of a quadratic function is linear. Here the derivative is 2x.
# The derivative of a cubic polynomial is a quadratic function. Here the derivative is 6x^2 - 2x.
# The derivative of an exponential function is itself. Here the derivative is 2^x.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the angle values (in radians)
theta = np.linspace(0, 2*np.pi, 400)

# Calculate sine, cosine, and tangent values
sin_values = np.sin(theta)
cos_values = np.cos(theta)
tan_values = np.tan(theta)

# Calculate derivatives (cosine function for sine derivative)
sin_derivative = np.cos(theta)
cos_derivative = -np.sin(theta)
tan_derivative = 1 / np.cos(theta)**2  # Derivative of tangent

# Create separate plots for sine, cosine, and tangent
fig, axs = plt.subplots(2, 1, figsize=(10, 18))

# Plot sine function and its derivative
axs[0].plot(theta, sin_values, label='$\sin(\\theta)$')
axs[0].plot(theta, sin_derivative, label="$\\frac{d}{d\\theta}[\sin(\\theta)] = \cos(\\theta)$", linestyle='--')
axs[0].set_xlabel('$\\theta$')
axs[0].set_ylabel('Value / Derivative Value')
axs[0].set_title('Sine Function and Its Derivative')
axs[0].legend()

# Plot cosine function and its derivative
axs[1].plot(theta, cos_values, label='$\cos(\\theta)$')
axs[1].plot(theta, cos_derivative, label="$\\frac{d}{d\\theta}[\cos(\\theta)] = -\sin(\\theta)$", linestyle='--')
axs[1].set_xlabel('$\\theta$')
axs[1].set_ylabel('Value / Derivative Value')
axs[1].set_title('Cosine Function and Its Derivative')
axs[1].legend()

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the angle values (in radians)
theta = np.linspace(-2, 2, 400)

# Calculate tanh values and its derivative
tanh_values = np.tanh(theta)
tanh_derivative = 1 - np.tanh(theta)**2  # Derivative of tanh

# Create a single plot
plt.figure(figsize=(10, 6))

# Plot tanh function and its derivative
plt.plot(theta, tanh_values, label='$\\tanh(\\theta)$')
plt.plot(theta, tanh_derivative, label="$\\frac{d}{d\\theta}[\\tanh(\\theta)] = 1 - \\tanh^2(\\theta)$", linestyle='--')

plt.xlabel('$\\theta$')
plt.ylabel('Value / Derivative Value')
plt.title('Hyperbolic Tangent Function (tanh) and Its Derivative')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x values
x = np.linspace(-5, 5, 400)

# Calculate e^x and its derivative
exp_x = np.exp(x)
exp_derivative = np.exp(x)

# Calculate softmax function
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x))

# Calculate ELU function
def elu(x, alpha=1.0):
    return np.where(x > 0, x, alpha * (np.exp(x) - 1))

# Create a single plot
plt.figure(figsize=(12, 8))

# Plot e^x and its derivative
plt.subplot(2, 2, 1)
plt.plot(x, exp_x, label='$e^x$')
plt.plot(x, exp_derivative, label="$\\frac{d}{dx}(e^x) = e^x$", linestyle='--')
plt.xlabel('x')
plt.ylabel('Value / Derivative Value')
plt.title('Exponential Function $e^x$ and Its Derivative')
plt.legend()


# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x values
x = np.linspace(0.1, 5, 400)

# Calculate natural logarithm and its derivative
ln_x = np.log(x)
derivative_ln_x = 1 / x

# Create a single plot
plt.figure(figsize=(10, 6))

# Plot natural logarithm and its derivative
plt.plot(x, ln_x, label='$\ln(x)$')
plt.plot(x, derivative_ln_x, label="$\dfrac{d}{dx}[\ln(x)] = \dfrac{1}{x}$", linestyle='--')

plt.xlabel('x')
plt.ylabel('Value / Derivative Value')
plt.title('Natural Logarithm ($\ln(x)$) and Its Derivative')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <a name="2.3"></a>
#
# ### Calculating Derivative

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the symbol
x = sp.symbols('x')

# Define the function
function = x**3 + 2*x**2 - 5*x + 2

# Calculate the derivative
derivative = sp.diff(function, x)

# Convert the SymPy expression to a Python function
f_lambdified = sp.lambdify(x, function, 'numpy')
derivative_lambdified = sp.lambdify(x, derivative, 'numpy')

# Generate x values
x_vals = np.linspace(-5, 5, 400)
y_vals = f_lambdified(x_vals)
derivative_vals = derivative_lambdified(x_vals)

# Create a plot
plt.figure(figsize=(10, 6))

# Plot the original function
plt.plot(x_vals, y_vals, label='$f(x) = x^3 + 2x^2 - 5x + 2$')

# Plot the derivative
plt.plot(x_vals, derivative_vals, label='$f\'(x)$', linestyle='--')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Function and Its Derivative')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <a name="2.4"></a>
#
# ### Non differentiable functions

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x values
x = np.linspace(-2, 2, 400)

# Define non-differentiable functions
abs_x = np.abs(x)
gap_function = np.piecewise(x, [x < -0.5, (x >= -0.5) & (x <= 0.5), x > 0.5], [-1, np.nan, 1])
floor_x = np.floor(x)
step_function = np.piecewise(x, [x < 0, x >= 0], [-1, 1])

# Create a plot
plt.figure(figsize=(10, 6))

# Plot absolute value function
plt.subplot(2, 2, 1)
plt.plot(x, abs_x)
plt.title('Absolute Value (|x|)')
plt.grid(True)

# Plot function with a gap
plt.subplot(2, 2, 2)
plt.plot(x, gap_function)
plt.title('Function with a Gap')
plt.grid(True)

# Plot floor function
plt.subplot(2, 2, 3)
plt.plot(x, floor_x)
plt.title('Floor Function (floor(x))')
plt.grid(True)

# Plot step function
plt.subplot(2, 2, 4)
plt.plot(x, step_function)
plt.title('Step Function')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <a name="2.5"></a>
#
# ### Optimization

# %% [markdown]
# **Squared loss (or mean squared error)** is a mathematical measure that calculates the average of the squared differences between predicted values and actual values in a dataset. It's commonly used in machine learning because it offers mathematical convenience, smooth optimization landscapes, and convexity, ensuring efficient and stable optimization. Squared loss also emphasizes larger errors, making it sensitive to outliers, which can be important for tasks like regression where we want to give more weight to significant errors.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a range of values for your guesses
guesses = np.linspace(-3, 6, 100)

# Define a quadratic loss function
def quadratic_loss(x):
    return (x - 2) ** 2

# Define an absolute loss function
def absolute_loss(x):
    return np.abs(x - 2)

# Calculate loss values
quadratic_losses = quadratic_loss(guesses)
absolute_losses = absolute_loss(guesses)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot quadratic loss (convex)
plt.plot(guesses, quadratic_losses, label='Quadratic Loss', color='blue')

# Plot absolute loss (non-convex)
plt.plot(guesses, absolute_losses, label='Absolute Loss', color='orange')

plt.xlabel('Guesses')
plt.ylabel('Loss')
plt.title('Comparison of Convex and Non-Convex Loss Functions')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Log loss, also known as cross-entropy loss or logistic loss**, is a loss function commonly used in machine learning for classification tasks. It measures the dissimilarity between predicted class probabilities and actual binary outcomes (0 or 1). Log loss penalizes confident but incorrect predictions more heavily, making it a suitable choice when optimizing models for accurate probability estimates.
#
# Log loss aligns well with maximum likelihood estimation, which is a common approach for estimating parameters in statistical models.

# %% [markdown]
# <a name="2.6"></a>
#
# ### Gradients

# %% [markdown]
# Functions with one variable and functions with two variables behave differently in terms of their structure and geometric interpretations. Additionally, tangent planes are important concepts when dealing with functions of two variables in the context of multivariable calculus.
#
# **Functions with One Variable:**
#
# A function with one variable, often denoted as f(x), takes a single input x and produces an output based on that input. The graph of a function with one variable is plotted in a two-dimensional space with the horizontal axis representing x and the vertical axis representing f(x). The graph is a curve that shows how the output changes as the input x varies.
#
# Tangent Line: For a function with one variable, the concept of a tangent line is used. The tangent line to a curve at a specific point is a straight line that touches the curve at that point without crossing it. The slope of the tangent line represents the instantaneous rate of change of the function at that point.
#
# **Functions with Two Variables:**
#
# A function with two variables, often denoted as f(x,y), takes two inputs x and y and produces an output based on those inputs. The graph of a function with two variables is plotted in a three-dimensional space, where the x and y values determine the height of the surface representing f(x,y).
#
# Tangent Plane: For a function with two variables, the concept of a tangent plane is used. The tangent plane to a surface at a specific point is a flat plane that touches the surface at that point without crossing it. The orientation of the tangent plane is determined by the partial derivatives of the function with respect to x and y at that point.
#
# **Geometric Interpretation:**
#
# The tangent line for a function with one variable represents the direction and rate of change of the function along a single direction. The tangent plane for a function with two variables represents the direction and rate of change of the function in the plane defined by the two input variables.
#
# In both cases, these tangent concepts help us understand the behavior of functions at specific points and provide insights into how the function changes as we move away from those points.
#
# In the context of optimization and multivariable calculus, tangent planes play a crucial role in approximating functions locally and understanding their behavior around specific points. They are used in the study of gradients, partial derivatives, and optimization methods for functions of multiple variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return x ** 2

def f_prime(x):
    return 2 * x

# Choose a point to find the tangent line
x_point = 2

# Calculate the tangent line equation
tangent_line = f_prime(x_point) * (np.linspace(x_point - 1, x_point + 1, 100) - x_point) + f(x_point)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(-2, 4, 100), f(np.linspace(-2, 4, 100)), label='Function $f(x)$')
plt.plot(np.linspace(x_point - 1, x_point + 1, 100), tangent_line, label='Tangent Line at $x = 2$')
plt.scatter(x_point, f(x_point), color='red', label='Tangent Point')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Single Variable Function with Tangent Line')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.lines import Line2D  # import Line2D for creating proxy artists

# Define the function and its partial derivatives
def f(x, y):
    return x**2 + y**2

def f_partial_x(x, y):
    return 2 * x

def f_partial_y(x, y):
    return 2 * y

# Choose a point to find the tangent plane
x_point = 1
y_point = 2

# Create a grid of x and y values
x_vals = np.linspace(-2, 2, 100)
y_vals = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Calculate the tangent plane equation
tangent_plane = f(x_point, y_point) + f_partial_x(x_point, y_point) * (X - x_point) + f_partial_y(x_point, y_point) * (Y - y_point)

# Create the 3D plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf1 = ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.6)
surf2 = ax.plot_surface(X, Y, tangent_plane, cmap='plasma', alpha=0.6)
point = ax.scatter(x_point, y_point, f(x_point, y_point), color='red', s=50)

# Create proxy artists for the legend
legend_elements = [Line2D([0], [0], color='b', lw=4, label='Function $f(x, y)$'),
                   Line2D([0], [0], color='orange', lw=4, label='Tangent Plane at (1, 2)'),
                   Line2D([0], [0], marker='o', color='w', markerfacecolor='r', markersize=10, label='Tangent Point')]
ax.legend(handles=legend_elements)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Two Variable Function with Tangent Plane')
plt.show()

# %% [markdown]
# **Partial derivatives** are a fundamental concept in calculus that allow us to understand how a function changes with respect to changes in its individual input variables, while keeping the other variables constant. In the context of functions of multiple variables, like those commonly encountered in machine learning (ML), partial derivatives provide insights into the rate of change of the function along each individual input dimension.
#
# Partial derivatives are crucial in optimization algorithms like gradient descent, where they guide the updates to model parameters in a direction that reduces the loss function. By calculating the partial derivatives of the loss function with respect to each parameter, gradient descent aims to find parameter values that minimize the loss.
#
# On a tangent plane we can illustrate partial derivative by cutting the plane and drawing a tangent line on the parabola in cross section.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function and its derivative
def f(x, y):
    return x**2 + y**2

def df_dx(x, y):
    return 2 * x

def df_dy(x, y):
    return 2 * y

# Choose a point to find the tangent line
x_point = 1.5
y_point = 1.5

# Calculate the function value and partial derivatives at the point
z_point = f(x_point, y_point)
partial_x = df_dx(x_point, y_point)
partial_y = df_dy(x_point, y_point)

# Create a grid of x and y values for the plot
x_vals = np.linspace(-2, 2, 100)
y_vals = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Calculate the tangent plane equation
tangent_plane = z_point + partial_x * (X - x_point) + partial_y * (Y - y_point)

# Create the plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the parabolic surface
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.2)

# Plot the tangent plane as a cut section
ax.contourf(X, Y, Z, levels=20, cmap='viridis', alpha=0.6)
ax.plot_surface(X, Y, tangent_plane, color='blue', alpha=0.5, linewidth=0)

# Plot the tangent line on the parabolic surface
tangent_x_vals = np.linspace(x_point - 1, x_point + 1, 100)
tangent_y_vals = (-partial_x / partial_y) * (tangent_x_vals - x_point) + y_point
tangent_z_vals = f(tangent_x_vals, tangent_y_vals)
ax.plot(tangent_x_vals, tangent_y_vals, tangent_z_vals, color='red', label='Tangent Line')

# Plot tangent point
ax.scatter(x_point, y_point, z_point, color='red', s=50, label='Tangent Point')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Tangent Plane and Tangent Line')
ax.legend()
plt.show()

# %% [markdown]
# The **gradient of a function** is represented as a vector that contains the partial derivatives of the function with respect to each of its input dimensions. In other words, the gradient is a multi-dimensional generalization of the concept of a derivative for functions with multiple variables.

# %% [markdown]
# <a name="2.7"></a>
#
# ### Gradient Descent

# %% [markdown]
# Gradient Descent is an optimization algorithm used to minimize a function iteratively. The basic idea is to update the parameters of a model in the direction of the negative gradient of a loss function. Intuitively, imagine you're on a hilly terrain (the function landscape) and your goal is to reach the lowest point (the minimum of the function). You start at an initial point and move in the direction of the steepest downhill slope (negative gradient) to eventually reach the lowest valley (the minimum of the function).
#
# Here's how the process works:
#
# Initialization: Choose a starting point (initial parameters) in the parameter space.
# Calculate Gradient: Compute the gradient of the loss function with respect to the parameters at the current point.
# Update Parameters: Move the parameters in the opposite direction of the gradient to reduce the loss. This is done by subtracting a fraction (learning rate) of the gradient from the current parameters.
# Repeat: Repeat steps 2 and 3 iteratively until convergence or a predefined number of steps.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return x**2

def df_dx(x):
    return 2 * x

# Gradient Descent parameters
learning_rate = 0.1
num_iterations = 20

# Initialization
x = 5  # Initial point

# Lists to store the values for visualization
x_history = []
f_history = []

# Gradient Descent iterations
for _ in range(num_iterations):
    x_history.append(x)
    f_history.append(f(x))

    # Calculate gradient and update x
    gradient = df_dx(x)
    x -= learning_rate * gradient

# Plot the function and the Gradient Descent path
x_vals = np.linspace(-6, 6, 400)
plt.plot(x_vals, f(x_vals), label='Function $f(x) = x^2$')
plt.scatter(x_history, f_history, color='red', label='Gradient Descent Path')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gradient Descent Illustration')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <a name="2.8"></a>
#
# ### Neural Network Optimization

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML # for displaying animation in notebook

# Define the sigmoid activation function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Simulated input features and target values
input_features = np.array([[0.2], [0.4], [0.6], [0.8]])
target_values = np.array([[0.3], [0.5], [0.7], [0.9]])

# Initialize random weights for the perceptron
weights = np.random.rand(1, 1)

# Hyperparameters
learning_rate = 0.1
num_epochs = 100

# Visualization setup
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.scatter(input_features, target_values, color='blue', label='Target Values')
initial_prediction_line, = ax1.plot(input_features, input_features * weights[0][0], color='red', label='Initial Prediction')
ax1.set_xlabel('Input Features')
ax1.set_ylabel('Target Values/Predicted Output')
ax1.set_title('Initial Prediction')
ax1.legend(loc='upper left')

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Mean Squared Error')
ax2.set_title('Training Progress')
ax2.grid(True)

# Animation update function
def animate(epoch):
    global weights


    # Forward pass
    predicted_output = sigmoid(np.dot(input_features, weights))

    # Calculate mean squared error
    error = target_values - predicted_output
    mse = np.mean(error**2)

    # Backpropagation
    adjustments = error * sigmoid_derivative(predicted_output)
    weights += np.dot(input_features.T, adjustments) * learning_rate

    # Visualization update
    if epoch % 10 == 0:
        initial_prediction_line.set_ydata(predicted_output)
        ax2.scatter(epoch, mse, color='blue', marker='o')
# Create the animation
animation = FuncAnimation(fig, animate, frames=num_epochs, interval=100, repeat=False)

# Convert the animation to HTML5 video and display it
HTML(animation.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# <a name="2.9"></a>
#
# ### Newtons Method
#
# In Gradient Descent, you start at a point and move in the direction opposite to the gradient (slope) of the function. This helps you move towards the minimum point of the function. You adjust your position iteratively by taking steps proportional to the gradient.
#
# Newton's Method in Terms of Gradient Descent:
#
# Newton's Method can be thought of as a more sophisticated version of Gradient Descent. Instead of moving only based on the gradient, Newton's Method also takes into account the curvature (second derivative) of the function.
#
# Imagine standing on a hilly landscape (the function you're optimizing). Gradient Descent would have you move in the steepest downhill direction based on the slope of the hill. Now, Newton's Method would add another layer: it would also consider how the hill curves and bends.
#
# Here's how:
#
# Gradient Step: Just like in Gradient Descent, you would first move in the direction of the steepest slope, just as you did before. This is the "gradient step" and is similar to what Gradient Descent does.
#
# Curvature Correction: But Newton's Method doesn't stop there. It takes into account the curvature of the hill. If the hill is gently sloping, you might overshoot the optimal point by following the gradient alone. Newton's Method corrects for this by making an additional adjustment based on the curvature of the hill. It's like learning how the hill's slope changes and using that information to make a smarter move.
#
# By combining the gradient and curvature information, Newton's Method often takes more efficient steps towards the optimal point. It can converge faster than plain Gradient Descent because it's not only looking at how steep the slope is but also how the slope changes.
#
# Choosing Between Gradient Descent and Newton's Method:
#
# You might wonder when to use each method. If you're dealing with a relatively simple function and have access to derivatives, Newton's Method can be very effective due to its faster convergence. However, if the function is complex or calculating derivatives is challenging, Gradient Descent might be a more practical choice since it's more robust and doesn't require as much function knowledge.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivatives
def f(x):
    return x**2 - 4*x + 4

def f_prime(x):
    return 2*x - 4

def f_double_prime(x):
    return 2

# Initialize variables
x_guess = 6.0
learning_rate = 0.1
num_iterations = 10

# Lists to store values for plotting
newton_x_vals = [x_guess]
gradient_x_vals = [x_guess]

# Newton's Method
for i in range(num_iterations):
    x_guess = x_guess - f_prime(x_guess) / f_double_prime(x_guess)
    newton_x_vals.append(x_guess)

# Gradient Descent
x_guess = 6.0
for i in range(num_iterations):
    x_guess = x_guess - learning_rate * f_prime(x_guess)
    gradient_x_vals.append(x_guess)

# Plotting
x_vals = np.linspace(0, 6, 100)
y_vals = f(x_vals)

plt.plot(x_vals, y_vals, label='Function: $f(x) = x^2 - 4x + 4$')
plt.plot(newton_x_vals, f(np.array(newton_x_vals)), marker='o', label="Newton's Method")
plt.plot(gradient_x_vals, f(np.array(gradient_x_vals)), marker='x', label='Gradient Descent')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title("Newton's Method vs Gradient Descent")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <a name="3"></a>
#
# ## Probability & Statistics

# %% [markdown]
# <a name="3.1"></a>
#
# ## Probability
#
# **Probability:**
# Probability is a measure of the likelihood of an event occurring. It's a number between 0 and 1, where 0 indicates an impossible event and 1 indicates a certain event. Probability is often denoted by the symbol P.
#
# Example: When rolling a fair six-sided die, the probability of rolling a 3 is 1/6 because there is one favorable outcome (rolling a 3) out of six possible outcomes.
#
# **Complement of Probability:**
# The complement of the probability of an event A (denoted as A') is the probability of event A not occurring. It's the probability of everything else happening except event A.
#
# Example: If the probability of rolling a 3 on a die is 1/6, then the probability of not rolling a 3 (complement) is 1 - 1/6 = 5/6.
#
# 3. Joint and Disjoint (Mutually Exclusive) Events:
#
# Joint Events: Joint events are events that occur together. The probability of joint events happening is denoted as P(A and B), where A and B are two different events.
# Example: When flipping a coin and rolling a die, the joint event of getting heads on the coin and rolling a 4 on the die has a probability of 1/2 * 1/6 = 1/12.
#
# Disjoint (Mutually Exclusive) Events: Disjoint events are events that cannot happen simultaneously. If one event occurs, the other cannot occur at the same time.
# Example: When drawing a card from a standard deck, the events "drawing a heart" and "drawing a spade" are disjoint because they cannot happen together in a single draw.
#
# 4. Sum of Probabilities for Joint and Disjoint Events:
#
# Joint Events: The sum of probabilities of joint events is calculated by adding the probabilities of each event occurring together.
# Example:
# Suppose we have a fair six-sided die, and we want to find the probability of rolling a 3 on the first roll and a 5 on the second roll.
#
# Probability of rolling a 3 on the first roll: P(3) = 1/6
# Probability of rolling a 5 on the second roll: P(5) = 1/6
# The probability of rolling a 3 on the first roll and a 5 on the second roll (joint event) is:
#
# P(3 and 5) = P(3) * P(5) = (1/6) * (1/6) = 1/36
#
# Disjoint (Mutually Exclusive) Events: The sum of probabilities of disjoint events is calculated by adding the probabilities of each individual event.
# Example: Drawing a card from a standard deck, the probability of drawing a heart or a spade (disjoint events) is P(heart or spade) = P(heart) + P(spade) = 1/4 + 1/4 = 1/2.

# %% [markdown]
# In Progress...

# %% [markdown]
# <a name="1"></a>
#
# ## Linear Algebra

# %% [markdown]
# In Progress...
